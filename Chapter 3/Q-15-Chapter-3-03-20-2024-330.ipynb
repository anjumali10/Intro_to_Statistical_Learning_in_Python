# %%
# Importing libraries and important packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP.models import (ModelSpec as MS,
summarize ,
poly)
import statsmodels.api as sm

# %%
# Loading dataset
from ISLP import load_data
boston_data = load_data('Boston')

# %%
boston_data.rename(columns = {'crim': 'crime_rate', 'zn': 'residential_land_zoned', 'indus': 'non-retail_business_acres',
                        'chas': 'charles_river', 'nox': 'nitrogen_oxides', 'rm': 'average_number_rooms', 'age': 'owner-occupied<1940',
                        'dis': 'dis_5_boston_emp_centers', 'rad': 'accessibility_radial_highways', 'tax': 'tax', 'ptratio': 'pupil_teacher_ratio',
                        'lstat': 'lower_status', 'medv': 'median_value'}, inplace = True)

# %%
boston_data
# Out:
#      crime_rate  residential_land_zoned  non-retail_business_acres  \
# 0       0.00632                    18.0                       2.31
# 1       0.02731                     0.0                       7.07
# 2       0.02729                     0.0                       7.07
# 3       0.03237                     0.0                       2.18
# 4       0.06905                     0.0                       2.18
# ..          ...                     ...                        ...
# 501     0.06263                     0.0                      11.93
# 502     0.04527                     0.0                      11.93
# 503     0.06076                     0.0                      11.93
# 504     0.10959                     0.0                      11.93
# 505     0.04741                     0.0                      11.93
#
#      charles_river  nitrogen_oxides  average_number_rooms  \
# 0                0            0.538                 6.575
# ...

# %% [markdown]
# ## (a) For each predictor, fit a simple linear regression model to predict the response. Describe your results.

# %% [markdown]
# ### residential_land_zoned to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['residential_land_zoned'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']

# %%
# Fit the model
model = sm.OLS(y, X)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           5.51e-06
# Time:                        13:21:12   Log-Likelihood:                -1796.0
# No. Observations:                 506   AIC:                             3596.
# Df Residuals:                     504   BIC:                             3604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('residential_land_zoned', 'crime_rate', label = 'Data points')
ax.set_xlabel('residential_land_zoned')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### non-retail_business_acres to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['non-retail_business_acres'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     99.82
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           1.45e-21
# Time:                        13:21:12   Log-Likelihood:                -1760.6
# No. Observations:                 506   AIC:                             3525.
# Df Residuals:                     504   BIC:                             3534.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
boston_data.columns
# Out:
# Index(['crime_rate', 'residential_land_zoned', 'non-retail_business_acres',
#        'charles_river', 'nitrogen_oxides', 'average_number_rooms',
#        'owner-occupied<1940', 'dis_5_boston_emp_centers',
#        'accessibility_radial_highways', 'tax', 'pupil_teacher_ratio',
#        'lower_status', 'median_value'],
#       dtype='object')

# %% [markdown]
# ### charles_river to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['charles_river'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.579
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):              0.209
# Time:                        13:21:13   Log-Likelihood:                -1805.6
# No. Observations:                 506   AIC:                             3615.
# Df Residuals:                     504   BIC:                             3624.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('charles_river', 'crime_rate', label = 'Data points')
ax.set_xlabel('charles_river')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### nitrogen_oxides to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['nitrogen_oxides'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     108.6
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           3.75e-23
# Time:                        13:21:13   Log-Likelihood:                -1757.0
# No. Observations:                 506   AIC:                             3518.
# Df Residuals:                     504   BIC:                             3526.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### average_number_rooms to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['average_number_rooms'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     25.45
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           6.35e-07
# Time:                        13:21:13   Log-Likelihood:                -1793.9
# No. Observations:                 506   AIC:                             3592.
# Df Residuals:                     504   BIC:                             3600.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### owner-occupied<1940 to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['owner-occupied<1940'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     71.62
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.85e-16
# Time:                        13:21:13   Log-Likelihood:                -1772.7
# No. Observations:                 506   AIC:                             3549.
# Df Residuals:                     504   BIC:                             3558.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('owner-occupied<1940', 'crime_rate', label = 'Data points')
ax.set_xlabel('owner-occupied<1940')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### dis_5_boston_emp_centers to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['dis_5_boston_emp_centers'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     84.89
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           8.52e-19
# Time:                        13:21:13   Log-Likelihood:                -1767.0
# No. Observations:                 506   AIC:                             3538.
# Df Residuals:                     504   BIC:                             3546.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('dis_5_boston_emp_centers', 'crime_rate', label = 'Data points')
ax.set_xlabel('dis_5_boston_emp_centers')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### accessibility_radial_highways to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['accessibility_radial_highways'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.69e-56
# Time:                        13:21:14   Log-Likelihood:                -1680.8
# No. Observations:                 506   AIC:                             3366.
# Df Residuals:                     504   BIC:                             3374.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('accessibility_radial_highways', 'crime_rate', label = 'Data points')
ax.set_xlabel('accessibility_radial_highways')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### tax to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['tax'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.36e-47
# Time:                        13:21:14   Log-Likelihood:                -1701.4
# No. Observations:                 506   AIC:                             3407.
# Df Residuals:                     504   BIC:                             3415.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -8.5284      0.816    -10.454      0.000     -10.131      -6.926
# ...

# %% [markdown]
# ### pupil_teacher_ratio to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['pupil_teacher_ratio'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     46.26
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.94e-11
# Time:                        13:21:14   Log-Likelihood:                -1784.1
# No. Observations:                 506   AIC:                             3572.
# Df Residuals:                     504   BIC:                             3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### lower_status to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['lower_status'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     132.0
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.65e-27
# Time:                        13:21:14   Log-Likelihood:                -1747.5
# No. Observations:                 506   AIC:                             3499.
# Df Residuals:                     504   BIC:                             3507.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# Create scatter plot to display relationship between variables
ax = boston_data.plot.scatter('lower_status', 'crime_rate', label = 'Data points')
ax.set_xlabel('lower_status')
ax.set_ylabel('crime_rate')
ax.legend();

# %% [markdown]
# ### median_value to predict crime rate

# %%
# Separate the predictor and response variable
design = MS(['median_value'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     89.49
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           1.17e-19
# Time:                        13:21:15   Log-Likelihood:                -1765.0
# No. Observations:                 506   AIC:                             3534.
# Df Residuals:                     504   BIC:                             3542.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## (b) Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis H0 : βj = 0?

# %%
# Separate the predictor and response variable
design = MS(['residential_land_zoned', 'non-retail_business_acres',
       'charles_river', 'nitrogen_oxides', 'average_number_rooms',
       'owner-occupied<1940', 'dis_5_boston_emp_centers',
       'accessibility_radial_highways', 'tax', 'pupil_teacher_ratio',
       'lower_status', 'median_value'])
X = design.fit_transform(boston_data)
y = boston_data['crime_rate']
# Fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     33.52
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           2.03e-56
# Time:                        13:21:15   Log-Likelihood:                -1655.4
# No. Observations:                 506   AIC:                             3337.
# Df Residuals:                     493   BIC:                             3392.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# * We can reject the null hypothesis for:
#   * residential_land_zoned
#   * dis_5_boston_emp_centers
#   * accessibility_radial_highways
#   * median_value

# %% [markdown]
# ## (c) Create a plot displaying the univariate regression coefcients from (a) on the x-axis, and the multiple regression coefcients from (b) on the y-axis.

# %%
predictors = ['residential_land_zoned', 'non-retail_business_acres',
       'charles_river', 'nitrogen_oxides', 'average_number_rooms',
       'owner-occupied<1940', 'dis_5_boston_emp_centers',
       'accessibility_radial_highways', 'tax', 'pupil_teacher_ratio',
       'lower_status', 'median_value']
linear_reg_coeff = [-0.0739, 0.5098, -1.8928, 31.2485, -2.6841, 0.1078, -1.5509, 0.6179, 0.0297, 1.1520, 0.5488, -0.3632]
linear_reg_coeff
# Out:
# [-0.0739,
#  0.5098,
#  -1.8928,
#  31.2485,
#  -2.6841,
#  0.1078,
#  -1.5509,
#  0.6179,
#  0.0297,
#  1.152,
#  0.5488,
#  -0.3632]

# %%
# Extracting coeff of multi regression
multi_reg_coeff = results.params[1:]
coeff = pd.DataFrame({'multi_reg_coeff': multi_reg_coeff, 'linear_reg_coeff': linear_reg_coeff})
coeff
# Out:
#                                multi_reg_coeff  linear_reg_coeff
# residential_land_zoned                0.045710           -0.0739
# non-retail_business_acres            -0.058350            0.5098
# charles_river                        -0.825378           -1.8928
# nitrogen_oxides                      -9.957587           31.2485
# average_number_rooms                  0.628911           -2.6841
# owner-occupied<1940                  -0.000848            0.1078
# dis_5_boston_emp_centers             -1.012247           -1.5509
# accessibility_radial_highways         0.612465            0.6179
# tax                                  -0.003776            0.0297
# pupil_teacher_ratio                  -0.304073            1.1520
# lower_status                          0.138801            0.5488
# median_value                         -0.220056           -0.3632

# %%
# Display scatter plot of coefficients of linear and multi regression
ax = coeff.plot.scatter('linear_reg_coeff', 'multi_reg_coeff', label = 'Predictors')
ax.set_xlabel('linear_reg_coeff')
ax.set_ylabel('multi_reg_coeff')
ax.legend();

# %% [markdown]
# ## (d) Is there evidence of non-linear association between any of the predictors and the response?

# %%
boston_data.columns
# Out:
# Index(['crime_rate', 'residential_land_zoned', 'non-retail_business_acres',
#        'charles_river', 'nitrogen_oxides', 'average_number_rooms',
#        'owner-occupied<1940', 'dis_5_boston_emp_centers',
#        'accessibility_radial_highways', 'tax', 'pupil_teacher_ratio',
#        'lower_status', 'median_value'],
#       dtype='object')

# %%
# Change the degree of polynomial
X = MS([poly('lower_status', degree=2), poly('owner-occupied<1940', degree=2), poly('dis_5_boston_emp_centers', degree=2)]).fit_transform(boston_data)
model3 = sm.OLS(y, X)
results3 = model3.fit()
summarize(results3)
# Out:
#                                                 coef  std err       t  P>|t|
# intercept                                     3.6135    0.323  11.186  0.000
# poly(lower_status, degree=2)[0]              57.2078    9.508   6.017  0.000
# poly(lower_status, degree=2)[1]              12.4067    7.700   1.611  0.108
# poly(owner-occupied<1940, degree=2)[0]      -18.3979   13.156  -1.398  0.163
# poly(owner-occupied<1940, degree=2)[1]        6.9540    8.008   0.868  0.386
# poly(dis_5_boston_emp_centers, degree=2)[0] -59.5159   11.712  -5.081  0.000
# poly(dis_5_boston_emp_centers, degree=2)[1]  42.6585    8.362   5.102  0.000

# %%
summarize(results)
# Out:
#                                   coef  std err      t  P>|t|
# intercept                      13.7784    7.082  1.946  0.052
# residential_land_zoned          0.0457    0.019  2.433  0.015
# non-retail_business_acres      -0.0584    0.084 -0.698  0.486
# charles_river                  -0.8254    1.183 -0.697  0.486
# nitrogen_oxides                -9.9576    5.290 -1.882  0.060
# average_number_rooms            0.6289    0.607  1.036  0.301
# owner-occupied<1940            -0.0008    0.018 -0.047  0.962
# dis_5_boston_emp_centers       -1.0122    0.282 -3.584  0.000
# accessibility_radial_highways   0.6125    0.088  6.997  0.000
# tax                            -0.0038    0.005 -0.730  0.466
# pupil_teacher_ratio            -0.3041    0.186 -1.632  0.103
# lower_status                    0.1388    0.076  1.833  0.067
# median_value                   -0.2201    0.060 -3.678  0.000
