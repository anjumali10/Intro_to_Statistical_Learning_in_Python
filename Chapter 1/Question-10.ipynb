# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### load in the Boston data set

# %%
boston = pd.read_csv('Boston.csv')

# %%
boston.rename(columns = {'crim': 'crime_rate', 'zn': 'residential_land_zoned', 'indus': 'non-retail_business_acres',
                        'chas': 'charles_river', 'nox': 'nitrogen_oxides', 'rm': 'average_number_rooms', 'age': 'owner-occupied<1940',
                        'dis': 'dis_5_boston_emp_centers', 'rad': 'accessibility_radial_highways', 'tax': 'tax', 'ptratio': 'pupil_teacher_ratio',
                        'lstat': 'lower_status', 'medv': 'median_value'}, inplace = True)

# %%
boston.head()
# Out:
#    crime_rate  residential_land_zoned  non-retail_business_acres  \
# 0     0.00632                    18.0                       2.31
# 1     0.02731                     0.0                       7.07
# 2     0.02729                     0.0                       7.07
# 3     0.03237                     0.0                       2.18
# 4     0.06905                     0.0                       2.18
#
#    charles_river  nitrogen_oxides  average_number_rooms  owner-occupied<1940  \
# 0              0            0.538                 6.575                 65.2
# 1              0            0.469                 6.421                 78.9
# 2              0            0.469                 7.185                 61.1
# 3              0            0.458                 6.998                 45.8
# 4              0            0.458                 7.147                 54.2
#
#    dis_5_boston_emp_centers  accessibility_radial_highways  tax  \
# 0                    4.0900                              1  296
# 1                    4.9671                              2  242
# 2                    4.9671                              2  242
# 3                    6.0622                              3  222
# 4                    6.0622                              3  222
#
#    pupil_teacher_ratio  lower_status  median_value
# 0                 15.3          4.98          24.0
# 1                 17.8          9.14          21.6
# 2                 17.8          4.03          34.7
# 3                 18.7          2.94          33.4
# 4                 18.7          5.33          36.2

# %% [markdown]
# #### How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
print('rows: ', boston.shape[0], '\ncolumns: ', boston.shape[1],
     '\nRows represents the suburbs and Columns represents the features of suburbs')
# Out:
# rows:  506
# columns:  13
# Rows represents the suburbs and Columns represents the features of suburbs

# %% [markdown]
# #### Make some pairwise scatterplots of the predictors

# %%
fig, ax = plt.subplots(figsize = (10, 10))
pd.plotting.scatter_matrix(boston[['crime_rate', 'tax', 'accessibility_radial_highways', 'lower_status']], ax = ax);
# Out:
# C:\Users\PCS\AppData\Local\Temp\ipykernel_8888\198254969.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(boston[['crime_rate', 'tax', 'accessibility_radial_highways', 'lower_status']], ax = ax);

# %% [markdown]
# #### Are any of the predictors associated with per capita crime rate?

# %% [markdown]
# #### Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
high_crime = boston['crime_rate'].describe().loc['75%']
high_pt_ratio = boston['pupil_teacher_ratio'].describe().loc['75%']
high_tax = boston['tax'].describe().loc['75%']

# %%
filtered_boston_high_crime = boston[boston['crime_rate'] > high_crime]
filtered_boston_high_crime.head()
# Out:
#      crime_rate  residential_land_zoned  non-retail_business_acres  \
# 143     4.09740                     0.0                      19.58
# 356     8.98296                     0.0                      18.10
# 357     3.84970                     0.0                      18.10
# 358     5.20177                     0.0                      18.10
# 359     4.26131                     0.0                      18.10
#
#      charles_river  nitrogen_oxides  average_number_rooms  \
# 143              0            0.871                 5.468
# 356              1            0.770                 6.212
# 357              1            0.770                 6.395
# 358              1            0.770                 6.127
# 359              0            0.770                 6.112
#
#      owner-occupied<1940  dis_5_boston_emp_centers  \
# 143                100.0                    1.4118
# 356                 97.4                    2.1222
# 357                 91.0                    2.5052
# 358                 83.4                    2.7227
# 359                 81.3                    2.5091
#
#      accessibility_radial_highways  tax  pupil_teacher_ratio  lower_status  \
# 143                              5  403                 14.7         26.42
# 356                             24  666                 20.2         17.60
# 357                             24  666                 20.2         13.27
# 358                             24  666                 20.2         11.48
# 359                             24  666                 20.2         12.67
#
#      median_value
# 143          15.6
# 356          17.8
# 357          21.7
# 358          22.7
# 359          22.6

# %%
filtered_boston_high_ratio = boston[boston['pupil_teacher_ratio'] > high_pt_ratio]
filtered_boston_high_ratio.head()
# Out:
#     crime_rate  residential_land_zoned  non-retail_business_acres  \
# 13     0.62976                     0.0                       8.14
# 14     0.63796                     0.0                       8.14
# 15     0.62739                     0.0                       8.14
# 16     1.05393                     0.0                       8.14
# 17     0.78420                     0.0                       8.14
#
#     charles_river  nitrogen_oxides  average_number_rooms  owner-occupied<1940  \
# 13              0            0.538                 5.949                 61.8
# 14              0            0.538                 6.096                 84.5
# 15              0            0.538                 5.834                 56.5
# 16              0            0.538                 5.935                 29.3
# 17              0            0.538                 5.990                 81.7
#
#     dis_5_boston_emp_centers  accessibility_radial_highways  tax  \
# 13                    4.7075                              4  307
# 14                    4.4619                              4  307
# 15                    4.4986                              4  307
# 16                    4.4986                              4  307
# 17                    4.2579                              4  307
#
#     pupil_teacher_ratio  lower_status  median_value
# 13                 21.0          8.26          20.4
# 14                 21.0         10.26          18.2
# 15                 21.0          8.47          19.9
# 16                 21.0          6.58          23.1
# 17                 21.0         14.67          17.5

# %%
filtered_boston_high_tax = boston[boston['tax'] > high_tax]
filtered_boston_high_tax.head()
# Out:
#      crime_rate  residential_land_zoned  non-retail_business_acres  \
# 488     0.15086                     0.0                      27.74
# 489     0.18337                     0.0                      27.74
# 490     0.20746                     0.0                      27.74
# 491     0.10574                     0.0                      27.74
# 492     0.11132                     0.0                      27.74
#
#      charles_river  nitrogen_oxides  average_number_rooms  \
# 488              0            0.609                 5.454
# 489              0            0.609                 5.414
# 490              0            0.609                 5.093
# 491              0            0.609                 5.983
# 492              0            0.609                 5.983
#
#      owner-occupied<1940  dis_5_boston_emp_centers  \
# 488                 92.7                    1.8209
# 489                 98.3                    1.7554
# 490                 98.0                    1.8226
# 491                 98.8                    1.8681
# 492                 83.5                    2.1099
#
#      accessibility_radial_highways  tax  pupil_teacher_ratio  lower_status  \
# 488                              4  711                 20.1         18.06
# 489                              4  711                 20.1         23.97
# 490                              4  711                 20.1         29.68
# 491                              4  711                 20.1         18.07
# 492                              4  711                 20.1         13.35
#
#      median_value
# 488          15.2
# 489           7.0
# 490           8.1
# 491          13.6
# 492          20.1

# %% [markdown]
# #### How many of the suburbs in this data set bound the Charles river?

# %%
charles_suburbs = boston[boston['charles_river'] == 1]
charles_suburbs.shape[0]
# Out:
# 35

# %% [markdown]
# #### What is the median pupil-teacher ratio among the towns in this data set?

# %%
median_pt_ratio = boston['pupil_teacher_ratio'].median()
median_pt_ratio
# Out:
# 19.05

# %% [markdown]
# #### Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors?

# %%
lowest_median = boston['median_value'].min()

# %%
lowest_median_suburb = boston[boston['median_value'] == lowest_median]
lowest_median_suburb
# Out:
#      crime_rate  residential_land_zoned  non-retail_business_acres  \
# 398     38.3518                     0.0                       18.1
# 405     67.9208                     0.0                       18.1
#
#      charles_river  nitrogen_oxides  average_number_rooms  \
# 398              0            0.693                 5.453
# 405              0            0.693                 5.683
#
#      owner-occupied<1940  dis_5_boston_emp_centers  \
# 398                100.0                    1.4896
# 405                100.0                    1.4254
#
#      accessibility_radial_highways  tax  pupil_teacher_ratio  lower_status  \
# 398                             24  666                 20.2         30.59
# 405                             24  666                 20.2         22.98
#
#      median_value
# 398           5.0
# 405           5.0

# %%
boston.describe()
# Out:
#        crime_rate  residential_land_zoned  non-retail_business_acres  \
# count  506.000000              506.000000                 506.000000
# mean     3.613524               11.363636                  11.136779
# std      8.601545               23.322453                   6.860353
# min      0.006320                0.000000                   0.460000
# 25%      0.082045                0.000000                   5.190000
# 50%      0.256510                0.000000                   9.690000
# 75%      3.677083               12.500000                  18.100000
# max     88.976200              100.000000                  27.740000
#
#        charles_river  nitrogen_oxides  average_number_rooms  \
# count     506.000000       506.000000            506.000000
# mean        0.069170         0.554695              6.284634
# std         0.253994         0.115878              0.702617
# min         0.000000         0.385000              3.561000
# 25%         0.000000         0.449000              5.885500
# 50%         0.000000         0.538000              6.208500
# 75%         0.000000         0.624000              6.623500
# max         1.000000         0.871000              8.780000
#
#        owner-occupied<1940  dis_5_boston_emp_centers  \
# count           506.000000                506.000000
# mean             68.574901                  3.795043
# std              28.148861                  2.105710
# min               2.900000                  1.129600
# 25%              45.025000                  2.100175
# 50%              77.500000                  3.207450
# 75%              94.075000                  5.188425
# max             100.000000                 12.126500
#
#        accessibility_radial_highways         tax  pupil_teacher_ratio  \
# count                     506.000000  506.000000           506.000000
# mean                        9.549407  408.237154            18.455534
# std                         8.707259  168.537116             2.164946
# min                         1.000000  187.000000            12.600000
# 25%                         4.000000  279.000000            17.400000
# 50%                         5.000000  330.000000            19.050000
# 75%                        24.000000  666.000000            20.200000
# max                        24.000000  711.000000            22.000000
#
#        lower_status  median_value
# count    506.000000    506.000000
# mean      12.653063     22.532806
# std        7.141062      9.197104
# min        1.730000      5.000000
# 25%        6.950000     17.025000
# 50%       11.360000     21.200000
# 75%       16.955000     25.000000
# max       37.970000     50.000000

# %% [markdown]
# #### In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling?

# %%
suburbs_seven_rooms = boston[boston['average_number_rooms'] > 7]
suburbs_seven_rooms.shape[0]
# Out:
# 64

# %%
suburbs_eight_rooms = boston[boston['average_number_rooms'] > 8]
suburbs_eight_rooms.shape[0]
# Out:
# 13

# %%
suburbs_eight_rooms.describe()
# Out:
#        crime_rate  residential_land_zoned  non-retail_business_acres  \
# count   13.000000               13.000000                  13.000000
# mean     0.718795               13.615385                   7.078462
# std      0.901640               26.298094                   5.392767
# min      0.020090                0.000000                   2.680000
# 25%      0.331470                0.000000                   3.970000
# 50%      0.520140                0.000000                   6.200000
# 75%      0.578340               20.000000                   6.200000
# max      3.474280               95.000000                  19.580000
#
#        charles_river  nitrogen_oxides  average_number_rooms  \
# count      13.000000        13.000000             13.000000
# mean        0.153846         0.539238              8.348538
# std         0.375534         0.092352              0.251261
# min         0.000000         0.416100              8.034000
# 25%         0.000000         0.504000              8.247000
# 50%         0.000000         0.507000              8.297000
# 75%         0.000000         0.605000              8.398000
# max         1.000000         0.718000              8.780000
#
#        owner-occupied<1940  dis_5_boston_emp_centers  \
# count            13.000000                 13.000000
# mean             71.538462                  3.430192
# std              24.608723                  1.883955
# min               8.400000                  1.801000
# 25%              70.400000                  2.288500
# 50%              78.300000                  2.894400
# 75%              86.500000                  3.651900
# max              93.900000                  8.906700
#
#        accessibility_radial_highways         tax  pupil_teacher_ratio  \
# count                      13.000000   13.000000            13.000000
# mean                        7.461538  325.076923            16.361538
# std                         5.332532  110.971063             2.410580
# min                         2.000000  224.000000            13.000000
# 25%                         5.000000  264.000000            14.700000
# 50%                         7.000000  307.000000            17.400000
# 75%                         8.000000  307.000000            17.400000
# max                        24.000000  666.000000            20.200000
#
#        lower_status  median_value
# count     13.000000     13.000000
# mean       4.310000     44.200000
# std        1.373566      8.092383
# min        2.470000     21.900000
# 25%        3.320000     41.700000
# 50%        4.140000     48.300000
# 75%        5.120000     50.000000
# max        7.440000     50.000000
